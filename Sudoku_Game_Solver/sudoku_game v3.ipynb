# %% [markdown]
# # Sudoku Game
#
#
# The rules of sudoku state that each row, column, and nonant must contain unique symbols; typically, the numbers 1 through 9.
#
# Through deduction and abstract reasoning, the player must fill in the blank spaces using logic based on the pre-populated symbols in the grid.
#
# The goal of this project is to create the basis for the game of sudoku in Python:
#     - viewable as a grid
#     -
#
#
#
# Secondarily, I'd like to examine the following potentials:
#
#     - solve all existing game boards (that are solvable with human logic)
#     - qualify the methodology by which players are able to solve the game:
#         - using abstract reasoning across the whole game board
#         - define techniques?
#
# As well as:
#     - be able to quantify the difficulty of a given game state
#
# ## Implementation Details
# - Each cell 'eliminates' the others in their respective row, column, and nonant when the value is imputed
# - grid.solve() function should imply the solve, for solvable boards

# %%
from src.grids import hard_game
from src.sudoku_grid import  SudokuGrid

# %%
a = SudokuGrid(show_steps=False)

hard_game(a)

# print(a.total_trues)

a.show_grid
# Out:
# <style type="text/css">
# #T_650a2_row0_col0, #T_650a2_row0_col1, #T_650a2_row0_col2, #T_650a2_row0_col6, #T_650a2_row0_col7, #T_650a2_row0_col8, #T_650a2_row1_col0, #T_650a2_row1_col1, #T_650a2_row1_col2, #T_650a2_row1_col6, #T_650a2_row1_col7, #T_650a2_row1_col8, #T_650a2_row2_col0, #T_650a2_row2_col1, #T_650a2_row2_col2, #T_650a2_row2_col6, #T_650a2_row2_col7, #T_650a2_row2_col8, #T_650a2_row3_col3, #T_650a2_row3_col4, #T_650a2_row3_col5, #T_650a2_row4_col3, #T_650a2_row4_col4, #T_650a2_row4_col5, #T_650a2_row5_col3, #T_650a2_row5_col4, #T_650a2_row5_col5, #T_650a2_row6_col0, #T_650a2_row6_col1, #T_650a2_row6_col2, #T_650a2_row6_col6, #T_650a2_row6_col7, #T_650a2_row6_col8, #T_650a2_row7_col0, #T_650a2_row7_col1, #T_650a2_row7_col2, #T_650a2_row7_col6, #T_650a2_row7_col7, #T_650a2_row7_col8, #T_650a2_row8_col0, #T_650a2_row8_col1, #T_650a2_row8_col2, #T_650a2_row8_col6, #T_650a2_row8_col7, #T_650a2_row8_col8 {
#   background-color: rgba(174, 214, 241, 0.6);
# ...

# %%
a.show_steps=True
a.solve()
# Out:
# <style type="text/css">
# #T_463c1_row0_col0, #T_463c1_row0_col1, #T_463c1_row0_col2, #T_463c1_row0_col6, #T_463c1_row0_col7, #T_463c1_row0_col8, #T_463c1_row1_col0, #T_463c1_row1_col1, #T_463c1_row1_col2, #T_463c1_row1_col6, #T_463c1_row1_col7, #T_463c1_row1_col8, #T_463c1_row2_col0, #T_463c1_row2_col1, #T_463c1_row2_col2, #T_463c1_row2_col6, #T_463c1_row2_col7, #T_463c1_row2_col8, #T_463c1_row3_col3, #T_463c1_row3_col4, #T_463c1_row3_col5, #T_463c1_row4_col3, #T_463c1_row4_col4, #T_463c1_row4_col5, #T_463c1_row5_col3, #T_463c1_row5_col4, #T_463c1_row5_col5, #T_463c1_row6_col0, #T_463c1_row6_col1, #T_463c1_row6_col2, #T_463c1_row6_col6, #T_463c1_row6_col7, #T_463c1_row6_col8, #T_463c1_row7_col0, #T_463c1_row7_col1, #T_463c1_row7_col2, #T_463c1_row7_col6, #T_463c1_row7_col7, #T_463c1_row7_col8, #T_463c1_row8_col0, #T_463c1_row8_col1, #T_463c1_row8_col2, #T_463c1_row8_col6, #T_463c1_row8_col7, #T_463c1_row8_col8 {
#   background-color: rgba(174, 214, 241, 0.6);
# ...
